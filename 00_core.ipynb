# %% [markdown]
# # core
#
# > Fill in a module description here

# %% [markdown]
# ![image.png](attachment:a8ab7d2c-e588-41d3-92a9-c1bb6b77c268.png)

# %% [markdown]
# ![image.png](attachment:08c717fe-833a-43cc-a762-f1a0baa357e6.png)

# %%
#| default_exp core

# %%
#| hide
from nbdev.showdoc import *

# %%
#| export
def foo(): pass

# %%
#| hide
import nbdev; nbdev.nbdev_export()
